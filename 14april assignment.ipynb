# %%
##importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer##handle missing values
from sklearn.preprocessing import StandardScaler##feature sclaing
from sklearn.preprocessing import OneHotEncoder##categorical to numerical 
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
##retrieving the dataset\
df=pd.read_csv('dataset.csv')
df.head()
##dividing our datset into dependent and independent features
X=df.iloc[:,:-1]
y=df['target']
##trainimng the model
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
##feature Engineering automation
num_pipeline=Pipeline(steps=[('imputer',SimpleImputer(strategy='median')),##handling missing values
                            ('scaler',StandardScaler())##feature scaling
                            ])
X_train=num_pipeline.fit_transform(X_train)
X_test=num_pipeline.transform(X_test)
##Model Training Automation
models={'Random Forest': RandomForestClassifier(),
        'Logistic Regression': LogisticRegression(),
        'Decision Tree': DecisionTreeClassifier()
       
       }
def evaluate_models(X_train,X_test,y_train,y_test,models):
    report={}
    for i in range(len(models)):
        model=list(models.values())[i]
        ##train model
        model.fit(X_train,y_train)
        ##predict testing data
        y_test_pred=model.predict(X_test)
        ##accuracy score
        test_model_score=accuracy_score(y_test,y_test_pred)
        report[list(models.keys())[i]]=test_model_score
        return report
print(evaluate_models(X_train,X_test,y_train,y_test,models))
classifier=RandomForestClassifier()
##hyperparameter tuning
params={'max_depth':[3,5,10,None],
       'n_estimators':[100,200,300],
       'criterion':['gini','entropy']}
cv=RandomizedSearchCV(classifier,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
cv.fit(X_train,y_train)
print('best parameters for model are:',cv.best_params_)
##tuning our model as best_prams
params1={'max_depth':[10],
       'n_estimators':[100],
       'criterion':['gini']}
cv=RandomizedSearchCV(classifier,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
cv.fit(X_train,y_train)
y_test_pred=model.predict(X_test)
test_model_score=accuracy_score(y_test,y_test_pred)
# Out:
# {'Random Forest': 0.8524590163934426}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.796 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.776 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.816 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.837 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=None, n_estimators=300;, score=0.796 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=None, n_estimators=300;, score=0.816 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=None, n_estimators=300;, score=0.812 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=None, n_estimators=300;, score=0.812 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=None, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.837 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.837 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.812 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.816 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.837 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.833 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.812 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.816 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.816 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.816 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.771 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=None, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=None, n_estimators=200;, score=0.857 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=None, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=None, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.816 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.750 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=300;, score=0.816 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=300;, score=0.837 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=300;, score=0.792 total time=   0.5s
# best parameters for model are: {'n_estimators': 200, 'max_depth': 3, 'criterion': 'gini'}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.796 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.833 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.796 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.837 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.833 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.771 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.816 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.837 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.857 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.837 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.837 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.837 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=200;, score=0.792 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.816 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.796 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.792 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.796 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.816 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=None, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.837 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.837 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.812 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.812 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.816 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.816 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.792 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.833 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=300;, score=0.833 total time=   0.5s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 62
#      60 cv=RandomizedSearchCV(classifier,param_distributions=params,scoring='accuracy',cv=5,verbose=3)
#      61 cv.fit(X_train,y_train)
# ---> 62 y_test_pred=model.predict(X_test)
#      63 test_model_score=accuracy_score(y_test,y_test_pred)
#
# NameError: name 'model' is not defined
